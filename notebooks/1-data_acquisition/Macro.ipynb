# %% [markdown]
# eur_interest_rate
# usd_interest_rate
# eurz_gdp
# us_gdp
# eurz_unrate
# us_unrate
# eurz_cpi
# us_cpi
# eurz_c02_emissions
# usd_c02_emissions

# %%
from fredapi import Fred
import pandas as pd

api_key = "bc34f268c5611c3e5ef29dc57eb41bd4"
fred = Fred(api_key=api_key)

# %%
#this function retrieves data from FRED api and renames the column of interest
def fredata(series_name, variable, start = '2004-01-01', end = '2024-01-01'):
    data = fred.get_series(series_name, start, end)
    df = pd.DataFrame({variable: data})
    return df.rename_axis('Date')

# %% [markdown]
# # GDPs (quarterly)

# %% [markdown]
# ## GDP US
# Units:Billions of Dollars, Seasonally Adjusted Annual Rate

# %%
gdp_us = fredata('GDP','gdp_us').resample('D').ffill()
gdp_us
# Out:
#                gdp_us
# Date
# 2004-01-01  11923.447
# 2004-01-02  11923.447
# 2004-01-03  11923.447
# 2004-01-04  11923.447
# 2004-01-05  11923.447
# ...               ...
# 2023-12-28  27956.998
# 2023-12-29  27956.998
# 2023-12-30  27956.998
# 2023-12-31  27956.998
# 2024-01-01  28284.498
#
# [7306 rows x 1 columns]

# %% [markdown]
# ## GDP Japan
# Units:Billions of Yen, Seasonally Adjusted

# %%
gdp_jp = fredata('JPNNGDP', 'gdp_jp').resample('D').ffill()
gdp_jp
# Out:
#               gdp_jp
# Date
# 2004-01-01  529365.1
# 2004-01-02  529365.1
# 2004-01-03  529365.1
# 2004-01-04  529365.1
# 2004-01-05  529365.1
# ...              ...
# 2023-12-28  598438.7
# 2023-12-29  598438.7
# 2023-12-30  598438.7
# 2023-12-31  598438.7
# 2024-01-01  598963.1
#
# [7306 rows x 1 columns]

# %% [markdown]
# ## GDP UK
# Units: Millions of Pounds, Seasonally Adjusted

# %%
gdp_uk = fredata('UKNGDP', 'gdp_uk').resample('D').ffill()
gdp_uk
# Out:
#               gdp_uk
# Date
# 2004-01-01  322790.0
# 2004-01-02  322790.0
# 2004-01-03  322790.0
# 2004-01-04  322790.0
# 2004-01-05  322790.0
# ...              ...
# 2023-09-27  678310.0
# 2023-09-28  678310.0
# 2023-09-29  678310.0
# 2023-09-30  678310.0
# 2023-10-01  677169.0
#
# [7214 rows x 1 columns]

# %% [markdown]
# ## GDP EuroZone
# Units: Millions of Euros, Seasonally Adjusted

# %%
gdp_ez = fredata('EUNNGDP', 'gdp_ez').resample('D').ffill()
gdp_ez
# Out:
#                gdp_ez
# Date
# 2004-01-01  2006218.2
# 2004-01-02  2006218.2
# 2004-01-03  2006218.2
# 2004-01-04  2006218.2
# 2004-01-05  2006218.2
# ...               ...
# 2023-09-27  3583513.2
# 2023-09-28  3583513.2
# 2023-09-29  3583513.2
# 2023-09-30  3583513.2
# 2023-10-01  3631513.0
#
# [7214 rows x 1 columns]

# %% [markdown]
# # Unemployment rate (monthly)

# %% [markdown]
# ## UN US
# Units: Percent, Seasonally Adjusted

# %%
unrate_us = fredata('UNRATE', 'unrate_us').resample('D').ffill()
unrate_us
# Out:
#             unrate_us
# Date
# 2004-01-01        5.7
# 2004-01-02        5.7
# 2004-01-03        5.7
# 2004-01-04        5.7
# 2004-01-05        5.7
# ...               ...
# 2023-12-28        3.7
# 2023-12-29        3.7
# 2023-12-30        3.7
# 2023-12-31        3.7
# 2024-01-01        3.7
#
# [7306 rows x 1 columns]

# %% [markdown]
# ## UN Japan

# %%
unrate_jp = fredata('LRUN64TTJPM156S', 'unrate_jp').resample('D').ffill()
unrate_jp
# Out:
#             unrate_jp
# Date
# 2004-01-01        5.1
# 2004-01-02        5.1
# 2004-01-03        5.1
# 2004-01-04        5.1
# 2004-01-05        5.1
# ...               ...
# 2023-12-28        2.5
# 2023-12-29        2.5
# 2023-12-30        2.5
# 2023-12-31        2.5
# 2024-01-01        2.6
#
# [7306 rows x 1 columns]

# %% [markdown]
# ## UN UK

# %%
unrate_uk = fredata('LRHUTTTTGBM156S', 'unrate_uk').resample('D').ffill()
unrate_uk
# Out:
#             unrate_uk
# Date
# 2004-01-01        4.8
# 2004-01-02        4.8
# 2004-01-03        4.8
# 2004-01-04        4.8
# 2004-01-05        4.8
# ...               ...
# 2023-12-28        4.0
# 2023-12-29        4.0
# 2023-12-30        4.0
# 2023-12-31        4.0
# 2024-01-01        4.2
#
# [7306 rows x 1 columns]

# %% [markdown]
# ## UN EZ

# %%
unrate_ez = fredata('LRHUTTTTEZM156S', 'unrate_ez').resample('D').ffill()
unrate_ez
# Out:
#             unrate_ez
# Date
# 2004-01-01        9.4
# 2004-01-02        9.4
# 2004-01-03        9.4
# 2004-01-04        9.4
# 2004-01-05        9.4
# ...               ...
# 2022-12-28        6.7
# 2022-12-29        6.7
# 2022-12-30        6.7
# 2022-12-31        6.7
# 2023-01-01        6.7
#
# [6941 rows x 1 columns]

# %% [markdown]
# # Monetary Base (M0, monthly)

# %% [markdown]
# ## M0 US
# Units: Billions of Dollars, Not Seasonally Adjusted

# %%
m0_us = fredata('BOGMBASE', 'm0_us').resample('D').ffill()
m0_us
# Out:
#                 m0_us
# Date
# 2004-01-01   736400.0
# 2004-01-02   736400.0
# 2004-01-03   736400.0
# 2004-01-04   736400.0
# 2004-01-05   736400.0
# ...               ...
# 2023-12-28  5827400.0
# 2023-12-29  5827400.0
# 2023-12-30  5827400.0
# 2023-12-31  5827400.0
# 2024-01-01  5843700.0
#
# [7306 rows x 1 columns]

# %% [markdown]
# ## M0 JP (monthly)
# Units: billions of jp
#
# Manually downloaded from Bank of Japan: https://www.stat-search.boj.or.jp/ssi/cgi-bin/famecgi2?cgi=$nme_s060_en

# %%
m0_jp = pd.read_csv('../../data/preparation/m0_jp.csv')

# %%
# Drop the first row
m0_jp = m0_jp.drop(0)

# Convert the first column to datetime
m0_jp['Series code'] = pd.to_datetime(m0_jp['Series code'], format='%Y/%m')

# Set the first column as the index
m0_jp.set_index('Series code', inplace=True)

#rename columns and daily forward fill
m0_jp.rename(columns = {'MD01\'MABS1AA12X12':'m0_jp'}, inplace = True)
m0_jp = m0_jp.rename_axis('Date').resample('D').ffill()

m0_jp = m0_jp.query("'2004-01-01' <= index <= '2024-01-01'")

# %%
m0_jp
# Out:
#               m0_jp
# Date
# 2004-01-01  1060327
# 2004-01-02  1060327
# 2004-01-03  1060327
# 2004-01-04  1060327
# 2004-01-05  1060327
# ...             ...
# 2023-12-28  6802590
# 2023-12-29  6802590
# 2023-12-30  6802590
# 2023-12-31  6802590
# 2024-01-01  6730163
#
# [7306 rows x 1 columns]

# %% [markdown]
# ## M0 UK
# https://tradingeconomics.com/united-kingdom/money-supply-m0

# %%
#m2_us = fredata('WM2NS', 'm2_us')
#m2_us

# %% [markdown]
# ## M0 Ez
# units: millions of euros
#
# https://data.ecb.europa.eu/data/datasets/ILM/ILM.M.U2.C.LT00001.Z5.EUR?chart_props=...%3D

# %%
m0_ez = pd.read_csv('../../data/preparation/m0_ez.csv')

# %%
# rename columns 
m0_ez.drop('TIME PERIOD', axis = 1,  inplace = True)
m0_ez.rename(columns = {'DATE':'Date','Base money (ILM.M.U2.C.LT00001.Z5.EUR)':'m0_ez'}, inplace=True)

# set Date as index and trnasform it to datetime object
m0_ez.set_index('Date', inplace = True)
m0_ez.index = pd.to_datetime(m0_ez.index)

# use the same periods as the rest of the series
m0_ez = m0_ez.query("'2004-01-01' <= index <= '2024-01-01'")

# transform it to daily frequency
m0_ez = m0_ez.resample('D').ffill()

# %%
m0_ez
# Out:
#               m0_ez
# Date
# 2004-01-31   561350
# 2004-02-01   561350
# 2004-02-02   561350
# 2004-02-03   561350
# 2004-02-04   561350
# ...             ...
# 2023-12-27  5306686
# 2023-12-28  5306686
# 2023-12-29  5306686
# 2023-12-30  5306686
# 2023-12-31  5271942
#
# [7275 rows x 1 columns]

# %% [markdown]
# # Interest rate

# %% [markdown]
# ## IR US

# %%
ir_us = fredata('FEDFUNDS', 'ir_us')

# %%
ir_us
# Out:
#             ir_us
# Date
# 2004-01-01   1.00
# 2004-02-01   1.01
# 2004-03-01   1.00
# 2004-04-01   1.00
# 2004-05-01   1.00
# ...           ...
# 2023-09-01   5.33
# 2023-10-01   5.33
# 2023-11-01   5.33
# 2023-12-01   5.33
# 2024-01-01   5.33
#
# [241 rows x 1 columns]

# %% [markdown]
# ## IR EZ
#
# Manually downloaded from ECB: https://data.ecb.europa.eu/main-figures/ecb-interest-rates-and-exchange-rates/key-ecb-interest-rates

# %%
ir_ez = pd.read_csv('../../data/preparation/ECB_irates.csv')

# %%
# Convert the first column to datetime
ir_ez['Date'] = pd.to_datetime(ir_ez['DATE'], format='%Y/%m/')

# Set the first column as the index
m0_jp.set_index('Series code', inplace=True)

#rename columns and daily forward fill
m0_jp.rename(columns = {'MD01\'MABS1AA12X12':'m0_jp'}, inplace = True)
m0_jp = m0_jp.rename_axis('Date').resample('D').ffill()

m0_jp = m0_jp.query("'2004-01-01' <= index <= '2024-01-01'")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 2
#       1 # Convert the first column to datetime
# ----> 2 ir_ez['Date'] = pd.to_datetime(ir_ez['DATE'], format='%Y/%m')
#       4 # Set the first column as the index
#       5 m0_jp.set_index('Series code', inplace=True)
#
# File c:\Users\usuario\anaconda3\envs\TFM\lib\site-packages\pandas\core\tools\datetimes.py:1112, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1110         result = arg.map(cache_array)
#    1111     else:
# -> 1112         values = convert_listlike(arg._values, format)
#    1113         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1114 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File c:\Users\usuario\anaconda3\envs\TFM\lib\site-packages\pandas\core\tools\datetimes.py:488, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     486 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     487 if format is not None and format != "mixed":
# --> 488     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     490 result, tz_parsed = objects_to_datetime64ns(
#     491     arg,
#     492     dayfirst=dayfirst,
#    (...)
#     496     allow_object=True,
#     497 )
#     499 if tz_parsed is not None:
#     500     # We can take a shortcut since the datetime64 numpy array
#     501     # is in UTC
#
# File c:\Users\usuario\anaconda3\envs\TFM\lib\site-packages\pandas\core\tools\datetimes.py:519, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     508 def _array_strptime_with_fallback(
#     509     arg,
#     510     name,
#    (...)
#     514     errors: str,
#     515 ) -> Index:
#     516     """
#     517     Call array_strptime, with fallback behavior depending on 'errors'.
#     518     """
# --> 519     result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     520     if any(tz is not None for tz in timezones):
#     521         return _return_parsed_timezone_results(result, timezones, utc, name)
#
# File strptime.pyx:534, in pandas._libs.tslibs.strptime.array_strptime()
#
# File strptime.pyx:355, in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: time data "1999-01-01" doesn't match format "%Y/%m", at position 0. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %%
ecb
# Out:
#             DATE  TIME PERIOD  \
# 0     1999-01-01  01 Jan 1999
# 1     1999-01-02  02 Jan 1999
# 2     1999-01-03  03 Jan 1999
# 3     1999-01-04  04 Jan 1999
# 4     1999-01-05  05 Jan 1999
# ...          ...          ...
# 9267  2024-05-16  16 May 2024
# 9268  2024-05-17  17 May 2024
# 9269  2024-05-18  18 May 2024
# 9270  2024-05-19  19 May 2024
# 9271  2024-05-20  20 May 2024
#
#       Deposit facility - date of changes (raw data) - Level (FM.D.U2.EUR.4F.KR.DFR.LEV)  \
# 0                                                  2.00
# 1                                                  2.00
# 2                                                  2.00
# 3                                                  2.75
# 4                                                  2.75
# ...                                                 ...
# 9267                                               4.00
# 9268                                               4.00
# 9269                                               4.00
# 9270                                               4.00
# 9271                                               4.00
#
#       Marginal lending facility - date of changes (raw data) - Level (FM.D.U2.EUR.4F.KR.MLFR.LEV)  \
# 0                                                  4.50
# 1                                                  4.50
# 2                                                  4.50
# 3                                                  3.25
# 4                                                  3.25
# ...                                                 ...
# 9267                                               4.75
# 9268                                               4.75
# 9269                                               4.75
# 9270                                               4.75
# 9271                                               4.75
#
#       Main refinancing operations - Minimum bid rate/fixed rate (date of changes) - Level (FM.D.U2.EUR.4F.KR.MRR_RT.LEV)
# 0                                                   3.0
# 1                                                   3.0
# 2                                                   3.0
# 3                                                   3.0
# 4                                                   3.0
# ...                                                 ...
# 9267                                                4.5
# 9268                                                4.5
# 9269                                                4.5
# 9270                                                4.5
# 9271                                                4.5
#
# [9272 rows x 5 columns]
