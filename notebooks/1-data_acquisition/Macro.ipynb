# %% [markdown]
# eur_interest_rate
# usd_interest_rate
# eurz_gdp
# us_gdp
# eurz_unrate
# us_unrate
# eurz_cpi
# us_cpi
# eurz_c02_emissions
# usd_c02_emissions

# %%
from fredapi import Fred
import pandas as pd

api_key = "bc34f268c5611c3e5ef29dc57eb41bd4"
fred = Fred(api_key=api_key)

# %%
#this function retrieves data from FRED api and renames the column of interest
def fredata(series_name, variable, start = '2004-01-01', end = '2024-01-01'):
    data = fred.get_series(series_name, start, end)
    df = pd.DataFrame({variable: data})
    return df.rename_axis('Date')

# %% [markdown]
# # GDPs (quarterly)

# %% [markdown]
# ## GDP US
# Units:Billions of Dollars, Seasonally Adjusted Annual Rate

# %%
gdp_us = fredata('GDP','gdp_us').resample('D').ffill()
gdp_us
# Out:
#                gdp_us
# Date
# 2004-01-01  11923.447
# 2004-01-02  11923.447
# 2004-01-03  11923.447
# 2004-01-04  11923.447
# 2004-01-05  11923.447
# ...               ...
# 2023-12-28  27956.998
# 2023-12-29  27956.998
# 2023-12-30  27956.998
# 2023-12-31  27956.998
# 2024-01-01  28284.498
#
# [7306 rows x 1 columns]

# %% [markdown]
# ## GDP Japan
# Units:Billions of Yen, Seasonally Adjusted

# %%
gdp_jp = fredata('JPNNGDP', 'gdp_jp').resample('D').ffill()
gdp_jp
# Out:
#               gdp_jp
# Date
# 2004-01-01  529365.1
# 2004-01-02  529365.1
# 2004-01-03  529365.1
# 2004-01-04  529365.1
# 2004-01-05  529365.1
# ...              ...
# 2023-12-28  598438.7
# 2023-12-29  598438.7
# 2023-12-30  598438.7
# 2023-12-31  598438.7
# 2024-01-01  598963.1
#
# [7306 rows x 1 columns]

# %% [markdown]
# ## GDP UK
# Units: Millions of Pounds, Seasonally Adjusted

# %%
gdp_uk = fredata('UKNGDP', 'gdp_uk').resample('D').ffill()
gdp_uk
# Out:
#               gdp_uk
# Date
# 2004-01-01  322790.0
# 2004-01-02  322790.0
# 2004-01-03  322790.0
# 2004-01-04  322790.0
# 2004-01-05  322790.0
# ...              ...
# 2023-09-27  678310.0
# 2023-09-28  678310.0
# 2023-09-29  678310.0
# 2023-09-30  678310.0
# 2023-10-01  677169.0
#
# [7214 rows x 1 columns]

# %% [markdown]
# ## GDP EuroZone
# Units: Millions of Euros, Seasonally Adjusted

# %%
gdp_ez = fredata('EUNNGDP', 'gdp_ez').resample('D').ffill()
gdp_ez
# Out:
#                gdp_ez
# Date
# 2004-01-01  2006218.2
# 2004-01-02  2006218.2
# 2004-01-03  2006218.2
# 2004-01-04  2006218.2
# 2004-01-05  2006218.2
# ...               ...
# 2023-09-27  3583513.2
# 2023-09-28  3583513.2
# 2023-09-29  3583513.2
# 2023-09-30  3583513.2
# 2023-10-01  3631513.0
#
# [7214 rows x 1 columns]

# %%
dfs_gdp = [gdp_us, gdp_uk, gdp_jp, gdp_ez]
gdp = pd.concat(dfs_gdp, axis=1)

# %%
gdp
# Out:
#                gdp_us    gdp_uk    gdp_jp     gdp_ez
# Date
# 2004-01-01  11923.447  322790.0  529365.1  2006218.2
# 2004-01-02  11923.447  322790.0  529365.1  2006218.2
# 2004-01-03  11923.447  322790.0  529365.1  2006218.2
# 2004-01-04  11923.447  322790.0  529365.1  2006218.2
# 2004-01-05  11923.447  322790.0  529365.1  2006218.2
# ...               ...       ...       ...        ...
# 2023-12-28  27956.998       NaN  598438.7        NaN
# 2023-12-29  27956.998       NaN  598438.7        NaN
# 2023-12-30  27956.998       NaN  598438.7        NaN
# 2023-12-31  27956.998       NaN  598438.7        NaN
# 2024-01-01  28284.498       NaN  598963.1        NaN
#
# [7306 rows x 4 columns]

# %% [markdown]
# # Unemployment rate (monthly)

# %% [markdown]
# ## UN US
# Units: Percent, Seasonally Adjusted

# %%
unrate_us = fredata('UNRATE', 'unrate_us').resample('D').ffill()
unrate_us
# Out:
#             unrate_us
# Date
# 2004-01-01        5.7
# 2004-01-02        5.7
# 2004-01-03        5.7
# 2004-01-04        5.7
# 2004-01-05        5.7
# ...               ...
# 2023-12-28        3.7
# 2023-12-29        3.7
# 2023-12-30        3.7
# 2023-12-31        3.7
# 2024-01-01        3.7
#
# [7306 rows x 1 columns]

# %% [markdown]
# ## UN Japan

# %%
unrate_jp = fredata('LRUN64TTJPM156S', 'unrate_jp').resample('D').ffill()
unrate_jp
# Out:
#             unrate_jp
# Date
# 2004-01-01        5.1
# 2004-01-02        5.1
# 2004-01-03        5.1
# 2004-01-04        5.1
# 2004-01-05        5.1
# ...               ...
# 2023-12-28        2.5
# 2023-12-29        2.5
# 2023-12-30        2.5
# 2023-12-31        2.5
# 2024-01-01        2.6
#
# [7306 rows x 1 columns]

# %% [markdown]
# ## UN UK

# %%
unrate_uk = fredata('LRHUTTTTGBM156S', 'unrate_uk').resample('D').ffill()
unrate_uk
# Out:
#             unrate_uk
# Date
# 2004-01-01        4.8
# 2004-01-02        4.8
# 2004-01-03        4.8
# 2004-01-04        4.8
# 2004-01-05        4.8
# ...               ...
# 2023-12-28        4.0
# 2023-12-29        4.0
# 2023-12-30        4.0
# 2023-12-31        4.0
# 2024-01-01        4.2
#
# [7306 rows x 1 columns]

# %% [markdown]
# ## UN EZ

# %%
unrate_ez = fredata('LRHUTTTTEZM156S', 'unrate_ez').resample('D').ffill()
unrate_ez
# Out:
#             unrate_ez
# Date
# 2004-01-01        9.4
# 2004-01-02        9.4
# 2004-01-03        9.4
# 2004-01-04        9.4
# 2004-01-05        9.4
# ...               ...
# 2022-12-28        6.7
# 2022-12-29        6.7
# 2022-12-30        6.7
# 2022-12-31        6.7
# 2023-01-01        6.7
#
# [6941 rows x 1 columns]

# %%
dfs_un = [unrate_us, unrate_uk, unrate_jp, unrate_ez]
unrate = pd.concat(dfs_un, axis=1)

# %%
unrate
# Out:
#             unrate_us  unrate_uk  unrate_jp  unrate_ez
# Date
# 2004-01-01        5.7        4.8        5.1        9.4
# 2004-01-02        5.7        4.8        5.1        9.4
# 2004-01-03        5.7        4.8        5.1        9.4
# 2004-01-04        5.7        4.8        5.1        9.4
# 2004-01-05        5.7        4.8        5.1        9.4
# ...               ...        ...        ...        ...
# 2023-12-28        3.7        4.0        2.5        NaN
# 2023-12-29        3.7        4.0        2.5        NaN
# 2023-12-30        3.7        4.0        2.5        NaN
# 2023-12-31        3.7        4.0        2.5        NaN
# 2024-01-01        3.7        4.2        2.6        NaN
#
# [7306 rows x 4 columns]

# %% [markdown]
# # Monetary Base (M0, monthly)

# %% [markdown]
# ## M0 US
# Units: Billions of Dollars, Not Seasonally Adjusted

# %%
m0_us = fredata('BOGMBASE', 'm0_us').resample('D').ffill()
m0_us
# Out:
#                 m0_us
# Date
# 2004-01-01   736400.0
# 2004-01-02   736400.0
# 2004-01-03   736400.0
# 2004-01-04   736400.0
# 2004-01-05   736400.0
# ...               ...
# 2023-12-28  5827400.0
# 2023-12-29  5827400.0
# 2023-12-30  5827400.0
# 2023-12-31  5827400.0
# 2024-01-01  5843700.0
#
# [7306 rows x 1 columns]

# %% [markdown]
# ## M0 JP (monthly)
# Units: billions of jp
#
# Manually downloaded from Bank of Japan: https://www.stat-search.boj.or.jp/ssi/cgi-bin/famecgi2?cgi=$nme_s060_en

# %%
m0_jp = pd.read_csv('../../data/preparation/m0_jp.csv')

# %%
# Drop the first row
m0_jp = m0_jp.drop(0)

# Convert the first column to datetime
m0_jp['Series code'] = pd.to_datetime(m0_jp['Series code'], format='%Y/%m')

# Set the first column as the index
m0_jp.set_index('Series code', inplace=True)

#rename columns and daily forward fill
m0_jp.rename(columns = {'MD01\'MABS1AA12X12':'m0_jp'}, inplace = True)
m0_jp = m0_jp.rename_axis('Date').resample('D').ffill()

m0_jp = m0_jp.query("'2004-01-01' <= index <= '2024-01-01'")

# %%
m0_jp
# Out:
#               m0_jp
# Date
# 2004-01-01  1060327
# 2004-01-02  1060327
# 2004-01-03  1060327
# 2004-01-04  1060327
# 2004-01-05  1060327
# ...             ...
# 2023-12-28  6802590
# 2023-12-29  6802590
# 2023-12-30  6802590
# 2023-12-31  6802590
# 2024-01-01  6730163
#
# [7306 rows x 1 columns]

# %% [markdown]
# ## M0 UK
# https://tradingeconomics.com/united-kingdom/money-supply-m0

# %%
#m2_us = fredata('WM2NS', 'm2_us')
#m2_us

# %% [markdown]
# ## M0 Ez
# units: millions of euros
#
# https://data.ecb.europa.eu/data/datasets/ILM/ILM.M.U2.C.LT00001.Z5.EUR?chart_props=...%3D

# %%
m0_ez = pd.read_csv('../../data/preparation/m0_ez.csv')

# %%
# rename columns 
m0_ez.drop('TIME PERIOD', axis = 1,  inplace = True)
m0_ez.rename(columns = {'DATE':'Date','Base money (ILM.M.U2.C.LT00001.Z5.EUR)':'m0_ez'}, inplace=True)

# set Date as index and trnasform it to datetime object
m0_ez.set_index('Date', inplace = True)
m0_ez.index = pd.to_datetime(m0_ez.index)

# use the same periods as the rest of the series
m0_ez = m0_ez.query("'2004-01-01' <= index <= '2024-01-01'")

# transform it to daily frequency
m0_ez = m0_ez.resample('D').ffill()

# %%
m0_ez
# Out:
#               m0_ez
# Date
# 2004-01-31   561350
# 2004-02-01   561350
# 2004-02-02   561350
# 2004-02-03   561350
# 2004-02-04   561350
# ...             ...
# 2023-12-27  5306686
# 2023-12-28  5306686
# 2023-12-29  5306686
# 2023-12-30  5306686
# 2023-12-31  5271942
#
# [7275 rows x 1 columns]

# %%
dfs_m0 = [m0_us, m0_jp, m0_ez]
m0 = pd.concat(dfs_m0, axis=1)

# %%
m0
# Out:
#                 m0_us    m0_jp      m0_ez
# Date
# 2004-01-01   736400.0  1060327        NaN
# 2004-01-02   736400.0  1060327        NaN
# 2004-01-03   736400.0  1060327        NaN
# 2004-01-04   736400.0  1060327        NaN
# 2004-01-05   736400.0  1060327        NaN
# ...               ...      ...        ...
# 2023-12-28  5827400.0  6802590  5306686.0
# 2023-12-29  5827400.0  6802590  5306686.0
# 2023-12-30  5827400.0  6802590  5306686.0
# 2023-12-31  5827400.0  6802590  5271942.0
# 2024-01-01  5843700.0  6730163        NaN
#
# [7306 rows x 3 columns]

# %% [markdown]
# # Interest rate
#
# Description: interest rate at which central banks lend money to commercial banks

# %% [markdown]
# ## IR US

# %%
ir_us = fredata('FEDFUNDS', 'ir_us').resample('D').ffill()

# %%
ir_us
# Out:
#             ir_us
# Date
# 2004-01-01   1.00
# 2004-01-02   1.00
# 2004-01-03   1.00
# 2004-01-04   1.00
# 2004-01-05   1.00
# ...           ...
# 2023-12-28   5.33
# 2023-12-29   5.33
# 2023-12-30   5.33
# 2023-12-31   5.33
# 2024-01-01   5.33
#
# [7306 rows x 1 columns]

# %% [markdown]
# ## IR EZ
#
# Manually downloaded from ECB: https://data.ecb.europa.eu/main-figures/ecb-interest-rates-and-exchange-rates/key-ecb-interest-rates

# %%
ir_ez = pd.read_csv('../../data/preparation/ECB_irates.csv')

# %%
# Convert the first column to datetime
ir_ez['DATE'] = pd.to_datetime(ir_ez['DATE'])
#pd.to_datetime(ir_ez['DATE'])

ir_ez.drop(['TIME PERIOD'], axis=1, inplace=True)


# Set the first column as the index
ir_ez.set_index('DATE', inplace=True)

ir_ez.rename(columns = {'Deposit facility - date of changes (raw data) - Level (FM.D.U2.EUR.4F.KR.DFR.LEV)':'ir_deposit_ez',
                         'Marginal lending facility - date of changes (raw data) - Level (FM.D.U2.EUR.4F.KR.MLFR.LEV)':'ir_lending_ez',
                         'Main refinancing operations - Minimum bid rate/fixed rate (date of changes) - Level (FM.D.U2.EUR.4F.KR.MRR_RT.LEV)': 'ir_MRO_ez' },
                         inplace = True)

# use the same periods as the rest of the series
ir_ez = ir_ez.query("'2004-01-01' <= index <= '2024-01-01'")

# transform it to daily frequency
ir_ez = ir_ez.resample('D').ffill()

# %%
ir_ez
# Out:
#             ir_deposit_ez  ir_lending_ez  ir_MRO_ez
# DATE
# 2004-01-01            1.0           3.00        2.0
# 2004-01-02            1.0           3.00        2.0
# 2004-01-03            1.0           3.00        2.0
# 2004-01-04            1.0           3.00        2.0
# 2004-01-05            1.0           3.00        2.0
# ...                   ...            ...        ...
# 2023-12-28            4.0           4.75        4.5
# 2023-12-29            4.0           4.75        4.5
# 2023-12-30            4.0           4.75        4.5
# 2023-12-31            4.0           4.75        4.5
# 2024-01-01            4.0           4.75        4.5
#
# [7306 rows x 3 columns]

# %% [markdown]
# ## IR JP

# %%
ir_jp = pd.read_csv('../../data/preparation/ir_jp.csv', delimiter = ';')

# %%
ir_jp
# Out:
#      Unnamed: 0 Unnamed: 1  Unnamed: 2  \
# 0           NaN        NaN         NaN
# 1           NaN        NaN         NaN
# 2        Period        NaN         NaN
# 3          2024        May        17.0
# 4           NaN        NaN        16.0
# ...         ...        ...         ...
# 5828        NaN        NaN         6.0
# 5829        NaN        NaN         3.0
# 5830        NaN        NaN         2.0
# 5831        NaN        NaN         NaN
# 5832        NaN        NaN         NaN
#
#                                              Unnamed: 3  \
# 0                                                   NaN
# 1                                                   NaN
# 2     Minimum bid rate in the Eurosystem's main refi...
# 3                                                  4,50
# 4                                                  4,50
# ...                                                 ...
# 5828                                               2,75
# 5829                                               2,75
# 5830                                               2,75
# 5831                                               2,75
# 5832                                                NaN
#
#                                            Unnamed: 4         Unnamed: 5  \
# 0                                                 NaN                NaN
# 1                                                 NaN                NaN
# 2     Japan: uncollateralized overnight call rate (2)  Sweden: repo rate
# 3                                                0,30               3,75
# 4                                                0,30               3,75
# ...                                               ...                ...
# 5828                                             0,10               3,75
# 5829                                              NaN               3,75
# 5830                                              NaN               3,75
# 5831                                             0,10               3,75
# 5832                                              NaN                NaN
#
#       Unnamed: 6                 Unnamed: 7  Unnamed: 8  \
# 0            NaN                        NaN         NaN
# 1            NaN                        NaN         NaN
# 2            NaN  United Kingdom: repo rate         NaN
# 3            NaN                       5,25         NaN
# 4            NaN                       5,25         NaN
# ...          ...                        ...         ...
# 5828         NaN                       4,00         NaN
# 5829         NaN                       4,00         NaN
# 5830         NaN                       4,00         NaN
# 5831         NaN                       4,00         NaN
# 5832         NaN                        NaN         NaN
#
#                     Unnamed: 9
# 0                          NaN
# 1                          NaN
# 2     US fed funds target rate
# 3                         5,50
# 4                         5,50
# ...                        ...
# 5828                      1,25
# 5829                      1,25
# 5830                      1,25
# 5831                      1,25
# 5832                       NaN
#
# [5833 rows x 10 columns]

# %% [markdown]
# ## IR UK
#
# Manually downloaded from Bank of England: https://www.bankofengland.co.uk/monetary-policy/the-interest-rate-bank-rate

# %%
ir_uk = pd.read_csv('../../data/preparation/ir_uk.csv', delimiter=';')

# %%
ir_uk.drop(['Unnamed: 2'], axis=1, inplace=True)

# Convert the 'Date' column to datetime
ir_uk['Date'] = pd.to_datetime(ir_uk['Date'])

# Set 'Date' as the index
ir_uk.set_index('Date', inplace=True)

# Create a date range that spans the full range of dates in the DataFrame
full_date_range = pd.date_range(start=ir_uk.index.min(), end='01/01/2024', freq='D')

# Reindex the DataFrame to the full date range
ir_uk = ir_uk.reindex(full_date_range)

# Forward fill the missing dates
ir_uk.ffill(inplace=True)

ir_uk.rename(columns={'Official Bank Rate' : 'ir_uk'}, inplace=True)

ir_uk = ir_uk.query("'2004-01-01' <= index <= '2024-01-01'")
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_13856\487728316.py:4: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   ir_uk['Date'] = pd.to_datetime(ir_uk['Date'])

# %%
ir_uk
# Out:
#            ir_uk
# 2004-01-01  3,75
# 2004-01-02  3,75
# 2004-01-03  3,75
# 2004-01-04  3,75
# 2004-01-05  3,75
# ...          ...
# 2023-12-28  5,25
# 2023-12-29  5,25
# 2023-12-30  5,25
# 2023-12-31  5,25
# 2024-01-01  5,25
#
# [7306 rows x 1 columns]

# %%
dfs_irate = [ir_us, ir_uk, ir_ez]
irate = pd.concat(dfs_irate, axis=1)

# %%
irate
# Out:
#             ir_us ir_uk  ir_deposit_ez  ir_lending_ez  ir_MRO_ez
# 2004-01-01   1.00  3,75            1.0           3.00        2.0
# 2004-01-02   1.00  3,75            1.0           3.00        2.0
# 2004-01-03   1.00  3,75            1.0           3.00        2.0
# 2004-01-04   1.00  3,75            1.0           3.00        2.0
# 2004-01-05   1.00  3,75            1.0           3.00        2.0
# ...           ...   ...            ...            ...        ...
# 2023-12-28   5.33  5,25            4.0           4.75        4.5
# 2023-12-29   5.33  5,25            4.0           4.75        4.5
# 2023-12-30   5.33  5,25            4.0           4.75        4.5
# 2023-12-31   5.33  5,25            4.0           4.75        4.5
# 2024-01-01   5.33  5,25            4.0           4.75        4.5
#
# [7306 rows x 5 columns]

# %% [markdown]
# # Concat all macro variabales datases

# %%
macro_dfs = [gdp, unrate, m0, irate]
macro = pd.concat(macro_dfs, axis=1)

# %%
macro
# Out:
#                gdp_us    gdp_uk    gdp_jp     gdp_ez  unrate_us  unrate_uk  \
# 2004-01-01  11923.447  322790.0  529365.1  2006218.2        5.7        4.8
# 2004-01-02  11923.447  322790.0  529365.1  2006218.2        5.7        4.8
# 2004-01-03  11923.447  322790.0  529365.1  2006218.2        5.7        4.8
# 2004-01-04  11923.447  322790.0  529365.1  2006218.2        5.7        4.8
# 2004-01-05  11923.447  322790.0  529365.1  2006218.2        5.7        4.8
# ...               ...       ...       ...        ...        ...        ...
# 2023-12-28  27956.998       NaN  598438.7        NaN        3.7        4.0
# 2023-12-29  27956.998       NaN  598438.7        NaN        3.7        4.0
# 2023-12-30  27956.998       NaN  598438.7        NaN        3.7        4.0
# 2023-12-31  27956.998       NaN  598438.7        NaN        3.7        4.0
# 2024-01-01  28284.498       NaN  598963.1        NaN        3.7        4.2
#
#             unrate_jp  unrate_ez      m0_us    m0_jp      m0_ez  ir_us ir_uk  \
# 2004-01-01        5.1        9.4   736400.0  1060327        NaN   1.00  3,75
# 2004-01-02        5.1        9.4   736400.0  1060327        NaN   1.00  3,75
# 2004-01-03        5.1        9.4   736400.0  1060327        NaN   1.00  3,75
# 2004-01-04        5.1        9.4   736400.0  1060327        NaN   1.00  3,75
# 2004-01-05        5.1        9.4   736400.0  1060327        NaN   1.00  3,75
# ...               ...        ...        ...      ...        ...    ...   ...
# 2023-12-28        2.5        NaN  5827400.0  6802590  5306686.0   5.33  5,25
# 2023-12-29        2.5        NaN  5827400.0  6802590  5306686.0   5.33  5,25
# 2023-12-30        2.5        NaN  5827400.0  6802590  5306686.0   5.33  5,25
# 2023-12-31        2.5        NaN  5827400.0  6802590  5271942.0   5.33  5,25
# 2024-01-01        2.6        NaN  5843700.0  6730163        NaN   5.33  5,25
#
#             ir_deposit_ez  ir_lending_ez  ir_MRO_ez
# 2004-01-01            1.0           3.00        2.0
# 2004-01-02            1.0           3.00        2.0
# 2004-01-03            1.0           3.00        2.0
# 2004-01-04            1.0           3.00        2.0
# 2004-01-05            1.0           3.00        2.0
# ...                   ...            ...        ...
# 2023-12-28            4.0           4.75        4.5
# 2023-12-29            4.0           4.75        4.5
# 2023-12-30            4.0           4.75        4.5
# 2023-12-31            4.0           4.75        4.5
# 2024-01-01            4.0           4.75        4.5
#
# [7306 rows x 16 columns]

# %%
#macro.to_csv('../../data/preparation/macro_variables.csv')
