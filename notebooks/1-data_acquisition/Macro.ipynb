# %% [markdown]
# eur_interest_rate
# usd_interest_rate
# eurz_gdp
# us_gdp
# eurz_unrate
# us_unrate
# eurz_cpi
# us_cpi
# eurz_c02_emissions
# usd_c02_emissions

# %%
from fredapi import Fred
import pandas as pd

api_key = "bc34f268c5611c3e5ef29dc57eb41bd4"
fred = Fred(api_key=api_key)

# %%
#this function retrieves data from FRED api and renames the column of interest
def fredata(series_name, variable, start = '2004-01-01', end = '2024-01-01'):
    data = fred.get_series(series_name, start, end)
    df = pd.DataFrame({variable: data})
    return df.rename_axis(None)

# %% [markdown]
# # GDPs (quarterly)

# %% [markdown]
# ## GDP US
# Units:Billions of Dollars, Seasonally Adjusted Annual Rate

# %%
gdp_us = fredata('GDP','gdp_us').resample('D').ffill()
gdp_us
# Out:
#                gdp_us
# 2004-01-01  11923.447
# 2004-01-02  11923.447
# 2004-01-03  11923.447
# 2004-01-04  11923.447
# 2004-01-05  11923.447
# ...               ...
# 2023-12-28  27956.998
# 2023-12-29  27956.998
# 2023-12-30  27956.998
# 2023-12-31  27956.998
# 2024-01-01  28284.498
#
# [7306 rows x 1 columns]

# %% [markdown]
# ## GDP Japan
# Units:Billions of Yen, Seasonally Adjusted

# %%
gdp_jp = fredata('JPNNGDP', 'gdp_jp').resample('D').ffill()
gdp_jp
# Out:
#               gdp_jp
# 2004-01-01  529368.3
# 2004-01-02  529368.3
# 2004-01-03  529368.3
# 2004-01-04  529368.3
# 2004-01-05  529368.3
# ...              ...
# 2023-09-27  594847.6
# 2023-09-28  594847.6
# 2023-09-29  594847.6
# 2023-09-30  594847.6
# 2023-10-01  598005.6
#
# [7214 rows x 1 columns]

# %% [markdown]
# ## GDP UK
# Units: Millions of Pounds, Seasonally Adjusted

# %%
gdp_uk = fredata('UKNGDP', 'gdp_uk').resample('D').ffill()
gdp_uk
# Out:
#               gdp_uk
# 2004-01-01  322790.0
# 2004-01-02  322790.0
# 2004-01-03  322790.0
# 2004-01-04  322790.0
# 2004-01-05  322790.0
# ...              ...
# 2023-09-27  678310.0
# 2023-09-28  678310.0
# 2023-09-29  678310.0
# 2023-09-30  678310.0
# 2023-10-01  677169.0
#
# [7214 rows x 1 columns]

# %% [markdown]
# ## GDP EuroZone
# Units: Millions of Euros, Seasonally Adjusted

# %%
gdp_ez = fredata('EUNNGDP', 'gdp_ez').resample('D').ffill()
gdp_ez
# Out:
#                gdp_ez
# 2004-01-01  2006218.2
# 2004-01-02  2006218.2
# 2004-01-03  2006218.2
# 2004-01-04  2006218.2
# 2004-01-05  2006218.2
# ...               ...
# 2023-09-27  3583513.2
# 2023-09-28  3583513.2
# 2023-09-29  3583513.2
# 2023-09-30  3583513.2
# 2023-10-01  3631513.0
#
# [7214 rows x 1 columns]

# %% [markdown]
# # Unemployment rate (monthly)

# %% [markdown]
# ## UN US
# Units: Percent, Seasonally Adjusted

# %%
unrate_us = fredata('UNRATE', 'unrate_us').resample('D').ffill()
unrate_us
# Out:
#             unrate_us
# 2004-01-01        5.7
# 2004-01-02        5.7
# 2004-01-03        5.7
# 2004-01-04        5.7
# 2004-01-05        5.7
# ...               ...
# 2023-12-28        3.7
# 2023-12-29        3.7
# 2023-12-30        3.7
# 2023-12-31        3.7
# 2024-01-01        3.7
#
# [7306 rows x 1 columns]

# %% [markdown]
# ## UN Japan

# %%
unrate_jp = fredata('LRUN64TTJPM156S', 'unrate_jp').resample('D').ffill()
unrate_jp
# Out:
#             unrate_jp
# 2004-01-01        5.1
# 2004-01-02        5.1
# 2004-01-03        5.1
# 2004-01-04        5.1
# 2004-01-05        5.1
# ...               ...
# 2023-12-28        2.5
# 2023-12-29        2.5
# 2023-12-30        2.5
# 2023-12-31        2.5
# 2024-01-01        2.6
#
# [7306 rows x 1 columns]

# %% [markdown]
# ## UN UK

# %%
unrate_uk = fredata('LRHUTTTTGBM156S', 'unrate_uk').resample('D').ffill()
unrate_uk
# Out:
#             unrate_uk
# 2004-01-01        4.8
# 2004-01-02        4.8
# 2004-01-03        4.8
# 2004-01-04        4.8
# 2004-01-05        4.8
# ...               ...
# 2023-11-27        3.8
# 2023-11-28        3.8
# 2023-11-29        3.8
# 2023-11-30        3.8
# 2023-12-01        3.9
#
# [7275 rows x 1 columns]

# %% [markdown]
# ## UN EZ

# %%
unrate_ez = fredata('LRHUTTTTEZM156S', 'unrate_ez').resample('D').ffill()
unrate_ez
# Out:
#             unrate_ez
# 2004-01-01        9.4
# 2004-01-02        9.4
# 2004-01-03        9.4
# 2004-01-04        9.4
# 2004-01-05        9.4
# ...               ...
# 2022-12-28        6.7
# 2022-12-29        6.7
# 2022-12-30        6.7
# 2022-12-31        6.7
# 2023-01-01        6.7
#
# [6941 rows x 1 columns]

# %% [markdown]
# # Money Supply (M2, weekly)

# %% [markdown]
# ## M2 US
# Units: Billions of Dollars, Not Seasonally Adjusted

# %%
m2_us = fredata('WM2NS', 'm2_us').resample('D').ffill()
m2_us
# Out:
#               m2_us
# 2004-01-05   6118.4
# 2004-01-06   6118.4
# 2004-01-07   6118.4
# 2004-01-08   6118.4
# 2004-01-09   6118.4
# ...             ...
# 2023-12-28  20901.4
# 2023-12-29  20901.4
# 2023-12-30  20901.4
# 2023-12-31  20901.4
# 2024-01-01  20883.4
#
# [7302 rows x 1 columns]

# %% [markdown]
# # M2 JP (monthly)
# Units: billions of jp
# Manually downloaded from ECB: https://data.ecb.europa.eu/data/datasets/RTD/RTD.M.JP.Y.M_M2.J?chart_props=...%3D%3D

# %%
m2_jp = pd.read_csv('M2_jp.csv')

# %%
m2_jp.columns
# Out:
# Index(['DATE', 'TIME PERIOD', 'MONEY STOCK M2, M-AV SA (RTD.M.JP.Y.M_M2.J)'], dtype='object')

# %%
m2_jp = m2_jp[['DATE', 'MONEY STOCK M2, M-AV SA (RTD.M.JP.Y.M_M2.J)']].rename(columns = {'MONEY STOCK M2, M-AV SA (RTD.M.JP.Y.M_M2.J)':'m2_jp'})

# %%
# Convertir la columna 'DATE' a formato de fecha
m2_jp['DATE'] = pd.to_datetime(m2_jp['DATE'])

# Establecer la columna 'DATE' como el índice del DataFrame
m2_jp.set_index('DATE', inplace=True)

# %%
m2_jp = m2_jp.resample('D').ffill()
m2_jp
# Out:
#                 m2_jp
# DATE
# 2003-04-30   672655.8
# 2003-05-01   672655.8
# 2003-05-02   672655.8
# 2003-05-03   672655.8
# 2003-05-04   672655.8
# ...               ...
# 2023-12-27  1240816.2
# 2023-12-28  1240816.2
# 2023-12-29  1240816.2
# 2023-12-30  1240816.2
# 2023-12-31  1242776.2
#
# [7551 rows x 1 columns]

# %% [markdown]
# ## M2 UK

# %%
m2_us = fredata('WM2NS', 'm2_us')
m2_us
