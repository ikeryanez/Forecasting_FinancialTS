# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.dates import DateFormatter

# %%
df = pd.read_csv('../../data/df_joint.csv')
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d', errors='coerce')
df.head()
# Out:
#         Date    eurusd    jpyusd    gbpusd      nq        sp500        nikkei  \
# 0 2004-01-01  1.258194  0.009320  1.785204  1468.0  1111.920044  10676.639648
# 1 2004-01-02  1.258194  0.009354  1.793690  1466.5  1108.479980  10676.639648
# 2 2004-01-05  1.268698  0.009413  1.807207  1495.5  1122.219971  10825.169922
# 3 2004-01-06  1.272103  0.009414  1.821295  1504.5  1123.670044  10813.990234
# 4 2004-01-07  1.264095  0.009418  1.817785  1517.0  1126.329956  10757.820312
#
#           ftse     gdp_us    gdp_uk  ...  unrate_ez     m0_us    m0_jp  \
# 0  4476.899902  11923.447  322790.0  ...        9.4  736400.0  1060327
# 1  4510.200195  11923.447  322790.0  ...        9.4  736400.0  1060327
# 2  4513.299805  11923.447  322790.0  ...        9.4  736400.0  1060327
# 3  4505.200195  11923.447  322790.0  ...        9.4  736400.0  1060327
# 4  4473.000000  11923.447  322790.0  ...        9.4  736400.0  1060327
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4957 entries, 0 to 4956
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           4957 non-null   datetime64[ns]
#  1   eurusd         4957 non-null   float64
#  2   jpyusd         4957 non-null   float64
#  3   gbpusd         4957 non-null   float64
#  4   nq             4957 non-null   float64
#  5   sp500          4957 non-null   float64
#  6   nikkei         4957 non-null   float64
#  7   ftse           4957 non-null   float64
#  8   gdp_us         4957 non-null   float64
#  9   gdp_uk         4957 non-null   float64
#  10  gdp_jp         4957 non-null   float64
#  11  gdp_ez         4957 non-null   float64
#  12  unrate_us      4957 non-null   float64
#  13  unrate_uk      4957 non-null   float64
#  14  unrate_jp      4957 non-null   float64
#  15  unrate_ez      4957 non-null   float64
#  16  m0_us          4957 non-null   float64
# ...

# %%
df.describe()
# Out:
#                                 Date       eurusd       jpyusd       gbpusd  \
# count                           4957  4957.000000  4957.000000  4957.000000
# mean   2013-07-01 14:23:39.084123392     1.246123     0.009625     1.555261
# min              2004-01-01 00:00:00     0.959619     0.006659     1.072754
# 25%              2008-10-01 00:00:00     1.135551     0.008795     1.335131
# 50%              2013-07-02 00:00:00     1.234598     0.009234     1.553109
# 75%              2018-04-02 00:00:00     1.336309     0.010104     1.721496
# max              2022-12-30 00:00:00     1.598798     0.013203     2.108192
# std                              NaN     0.126117     0.001345     0.235829
#
#                  nq        sp500        nikkei         ftse        gdp_us  \
# count   4957.000000  4957.000000   4957.000000  4957.000000   4957.000000
# mean    4763.666144  2026.416641  16572.700341  6195.103086  17566.198817
# ...

# %%
null_values = df.isnull().sum()
null_values
# Out:
# Date             0
# eurusd           0
# jpyusd           0
# gbpusd           0
# nq               0
# sp500            0
# nikkei           0
# ftse             0
# gdp_us           0
# gdp_uk           0
# gdp_jp           0
# gdp_ez           0
# unrate_us        0
# unrate_uk        0
# unrate_jp        0
# unrate_ez        0
# m0_us            0
# m0_jp            0
# m0_ez            0
# ir_us            0
# ir_uk            0
# ir_deposit_ez    0
# ir_lending_ez    0
# ir_MRO_ez        0
# ir_jp            0
# dtype: int64

# %%
# Función auxiliar para formatear el eje x
def format_xaxis(ax):
    ax.xaxis.set_major_formatter(DateFormatter("%Y"))
    ax.figure.autofmt_xdate()

# Celda 8: Visualizar las series temporales de los tipos de cambio
plt.figure(figsize=(14, 7))
plt.plot(df['Date'], df['eurusd'], label='EUR/USD')
plt.plot(df['Date'], df['jpyusd'], label='JPY/USD')
plt.plot(df['Date'], df['gbpusd'], label='GBP/USD')
plt.xlabel('Date')
plt.ylabel('Exchange Rate')
plt.title('Exchange Rates Over Time')
plt.legend()
format_xaxis(plt.gca())
plt.show()

# %%
# Celda 9: Visualizar las series temporales de los índices bursátiles
plt.figure(figsize=(14, 7))
plt.plot(df['Date'], df['nq'], label='Nasdaq 100')
plt.plot(df['Date'], df['sp500'], label='S&P 500')
plt.plot(df['Date'], df['nikkei'], label='Nikkei 225')
plt.plot(df['Date'], df['ftse'], label='FTSE 100')
plt.xlabel('Date')
plt.ylabel('Index Value')
plt.title('Stock Indices Over Time')
plt.legend()
format_xaxis(plt.gca())
plt.show()

# %%
# Celda 10: Visualizar series temporales de PIB de diferentes regiones
plt.figure(figsize=(14, 7))
plt.plot(df['Date'], df['gdp_us'], label='GDP US')
plt.plot(df['Date'], df['gdp_uk'], label='GDP UK')
plt.plot(df['Date'], df['gdp_jp'], label='GDP JP')
plt.plot(df['Date'], df['gdp_ez'], label='GDP EZ')
plt.xlabel('Date')
plt.ylabel('GDP')
plt.title('GDP Over Time')
plt.legend()
format_xaxis(plt.gca())
plt.show()

# %%
plt.figure(figsize=(14, 7))
plt.plot(df['Date'], df['unrate_us'], label='Unemployment Rate US')
plt.plot(df['Date'], df['unrate_uk'], label='Unemployment Rate UK')
plt.plot(df['Date'], df['unrate_jp'], label='Unemployment Rate JP')
plt.plot(df['Date'], df['unrate_ez'], label='Unemployment Rate EZ')
plt.xlabel('Date')
plt.ylabel('Unemployment Rate')
plt.title('Unemployment Rates Over Time')
plt.legend()
format_xaxis(plt.gca())
plt.show()

# %%
plt.figure(figsize=(14, 7))
plt.plot(df['Date'], df['ir_us'], label='Interest Rate US')
plt.plot(df['Date'], df['ir_uk'], label='Interest Rate UK')
plt.plot(df['Date'], df['ir_deposit_ez'], label='Deposit Rate EZ')
plt.plot(df['Date'], df['ir_jp'], label='Interest Rate JP')
plt.xlabel('Date')
plt.ylabel('Interest Rate')
plt.title('Interest Rates Over Time')
plt.legend()
format_xaxis(plt.gca())
plt.show()

# %%
plt.figure(figsize=(14, 7))
plt.plot(df['Date'], df['m0_us'], label='M0 US')
plt.plot(df['Date'], df['m0_jp'], label='M0 JP')
plt.plot(df['Date'], df['m0_ez'], label='M0 EZ')
plt.xlabel('Date')
plt.ylabel('M0')
plt.title('Monetary Base (M0) Over Time')
plt.legend()
format_xaxis(plt.gca())
plt.show()
